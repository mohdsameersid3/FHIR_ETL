# %%
from src.bronze.bronze_loader import BronzeLoader
from src.common.spark import SparkSessionManager

spark = SparkSessionManager().get_session()

loader = BronzeLoader(spark)


df = loader.load('Patient')
print(type(df))

print(f"Number of records: {df.count()}")

# %%
print(
    dbutils.fs.head(
        "/Volumes/workspace/default/FHIR/raw/Patient/2026-07-19/page_00001.json",
        500
    )
)

# %%
display(
    dbutils.fs.ls("/Volumes/workspace/default/FHIR/raw/Patient/2026-07-19")
)

# %%
raw = spark.table("workspace.bronze.patient")

# %%
raw.display()

# %%
spark.sql("SHOW TABLES IN workspace.default").show(truncate=False)

# %%
spark.sql("DROP TABLE workspace.default.silver_condition").show(truncate=False)

# %%
# %sql
CREATE SCHEMA bronze;
CREATE SCHEMA silver;
CREATE SCHEMA gold;
